# %% [markdown]
# <a href="https://colab.research.google.com/github/23Aditya/Character-recognition/blob/main/Character_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install and Import Dependencies

# %%
import cv2

# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %% [markdown]
# ## 2. Image loading and text recognition using EasyOCR

# %%
reader = easyocr.Reader(['en'])

# %% [markdown]
# ## 3.Loading image for data extraction

# %%
Image("Letter.jpg")

# %% [markdown]
# ## 4. Output

# %%
output = reader.readtext_batched('Letter.jpg')
output
# Out:
# [[([[110, 64], [340, 64], [340, 114], [110, 114]],
#    'In Scarch of',
#    0.2816768038550055),
#   ([[380, 68], [593, 68], [593, 110], [380, 110]],
#    'Tersonal Ia',
#    0.734482010883589),
#   ([[33, 211], [732, 211], [732, 265], [33, 265]],
#    'ABCDEFGHIJKLMNOPQRSTUVWXYE',
#    0.7081923088253956),
#   ([[26, 253], [678, 253], [678, 328], [26, 328]],
#    'abcAefghijklmncPirstuvwxjz',
#    0.22651335913209922),
#   ([[35, 356], [666, 356], [666, 417], [35, 417]],
#    'Wtit T bouqh( his Telikan _MIBIN',
#    0.061305184596803605),
#   ([[35, 404], [870, 404], [870, 459], [35, 459]],
#    'RichavA Binderdnd hadl Mhexil Lonvevtc (',
#    0.06301347520073514),
#   ([[78, 456], [336, 456], [336, 506], [78, 506]],
#    'Cusina ialz',
#    0.3562697181887096),
#   ([[352, 456], [656, 456], [656, 504], [352, 504]],
#    'I Ex Was_stil(',
#    0.12504060451008447),
#   ([[37, 507], [95, 507], [95, 547], [37, 547]], 'Rr', 0.10582677395235311),
# ...

# %%
cord = output[0][0]

# %%
image = cv2.imread('Letter.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,225),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
